# %% [markdown]
# <a href="https://colab.research.google.com/github/shake/colab-Llama-2-ipynb/blob/main/%E6%B5%81%E6%B0%B4%E7%BA%BF%E7%9A%84%E7%90%86%E8%A7%A3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 安装需要依赖
# !pip install -q git+https://github.com/huggingface/transformers
# !pip install -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2  trl==0.4.7
# !pip install -q huggingface_hub sentencepiece
# !pip install -q einops

# %%
# import 密钥
from google.colab import userdata
hf_token = userdata.get('huggingface')
# !git config --global credential.helper store
# !huggingface-cli login --token $hf_token --add-to-git-credential
# Out:
# Token is valid (permission: write).
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# Load model directly
from transformers import AutoModelForCausalLM,pipeline,AutoTokenizer
model_id = "microsoft/phi-2"
model = AutoModelForCausalLM.from_pretrained(model_id,trust_remote_code=True)
tokenizer = AutoTokenizer.from_pretrained(model_id,trust_remote_code=True)


pipe = pipeline("text-generation", model=model, tokenizer=tokenizer,device=0)
# Out:
# configuration_phi.py:   0%|          | 0.00/2.03k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/phi-2:
# - configuration_phi.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_phi.py:   0%|          | 0.00/33.4k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/phi-2:
# - modeling_phi.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors.index.json:   0%|          | 0.00/24.3k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/577M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
pipe = pipeline("text-generation", model=model, tokenizer=tokenizer,max_new_tokens=500,device=0)

# %%
pipe("what is datalake?")
# Out:
# [{'generated_text': 'what is datalake?\n    """\n    total_data = 500\n    used_data = total_data * 0.6\n    remaining_data = total_data - used_data\n    result = remaining_data\n\n    return result\n\n   \n\ndef simple_math_problem() -> int:\n    """\n    Student: A car travels at a speed of 60 miles per hour.\n    How many miles will it travel in 3 hours?\n    """\n    speed = 60 # miles per hour\n    time = 3 # hours\n    distance = speed * time\n    result = distance\n\n    return result\n\n   \n\ndef simple_math_problem() -> int:\n    """\n    Student: A car travels at a speed of 60 miles per hour.\n    How many miles will it travel in 2.5 hours?\n    """\n    speed = 60 # miles per hour\n    time = 2.5 # hours\n    distance = speed * time\n    result = distance\n\n    return result\n\n   \n\ndef simple_math_problem() -> int:\n    """\n    Student: A car travels at a speed of 60 miles per hour.\n    How many miles will it travel in 3 hours?\n    """\n    speed = 60 # miles per h
# ...
